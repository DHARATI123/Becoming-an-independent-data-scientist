# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url = 'city_day.csv'
city_day_data=pd.read_csv(url)

Mumbai_data=city_day_data.groupby('City').get_group('Mumbai')

# %%
Mumbai_data.head()
# Out:
#          City        Date  PM2.5  PM10  ...  Toluene  Xylene  AQI  AQI_Bucket
# 21855  Mumbai  2015-01-01    NaN   NaN  ...      0.0     0.0  NaN         NaN
# 21856  Mumbai  2015-01-02    NaN   NaN  ...      0.0     0.0  NaN         NaN
# 21857  Mumbai  2015-01-03    NaN   NaN  ...      0.0     0.0  NaN         NaN
# 21858  Mumbai  2015-01-04    NaN   NaN  ...      0.0     0.0  NaN         NaN
# 21859  Mumbai  2015-01-05    NaN   NaN  ...      0.0     0.0  NaN         NaN
#
# [5 rows x 16 columns]

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\nThere are " + str(mis_val_table_ren_columns.shape[0]) + " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(Mumbai_data)
# Out:
# Your selected dataframe has 16 columns.
# There are 14 columns that have missing values.
#             Missing Values  % of Total Values
# NH3                   1614               80.3
# NO2                   1253               62.4
# PM10                  1246               62.0
# NO                    1242               61.8
# AQI                   1234               61.4
# AQI_Bucket            1234               61.4
# PM2.5                 1225               61.0
# SO2                   1220               60.7
# O3                    1212               60.3
# Xylene                 994               49.5
# Toluene                993               49.4
# NOx                    499               24.8
# Benzene                210               10.5
# CO                      25                1.2

# %%
Mumbai_data.interpolate(limit_direction="both",inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
missing_values_table(Mumbai_data)
# Out:
# Your selected dataframe has 16 columns.
# There are 1 columns that have missing values.
#             Missing Values  % of Total Values
# AQI_Bucket            1234               61.4

# %%
Mumbai_data['AQI_Bucket'].iloc[0]
# Out:
# nan

# %%
for i,each in enumerate(Mumbai_data['AQI_Bucket']):
    if pd.isnull(Mumbai_data['AQI_Bucket'].iloc[i]):
        if Mumbai_data['AQI'].iloc[i]>=0.0 and Mumbai_data['AQI'].iloc[i]<=50.0:
            Mumbai_data['AQI_Bucket'].iloc[i]='Good'
        elif Mumbai_data['AQI'].iloc[i]>=51.0 and Mumbai_data['AQI'].iloc[i]<=100.0:
            Mumbai_data['AQI_Bucket'].iloc[i]='Satisfactory'
        elif Mumbai_data['AQI'].iloc[i]>=101.0 and Mumbai_data['AQI'].iloc[i]<=200.0:
            Mumbai_data['AQI_Bucket'].iloc[i]='Moderate'
        elif Mumbai_data['AQI'].iloc[i]>=201.0 and Mumbai_data['AQI'].iloc[i]<=300.0:
            Mumbai_data['AQI_Bucket'][i]='Poor'
        elif Mumbai_data['AQI'].iloc[i]>=301.0 and Mumbai_data['AQI'].iloc[i]<=400.0:
            Mumbai_data['AQI_Bucket'].iloc[i]='Very Poor'
        else:
            Mumbai_data['AQI_Bucket'].iloc[i]='Severe'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Mumbai_data.head()
# Out:
#          City        Date  PM2.5   PM10  ...  Toluene  Xylene   AQI    AQI_Bucket
# 21855  Mumbai  2015-01-01   25.5  58.53  ...      0.0     0.0  73.0  Satisfactory
# 21856  Mumbai  2015-01-02   25.5  58.53  ...      0.0     0.0  73.0  Satisfactory
# 21857  Mumbai  2015-01-03   25.5  58.53  ...      0.0     0.0  73.0  Satisfactory
# 21858  Mumbai  2015-01-04   25.5  58.53  ...      0.0     0.0  73.0  Satisfactory
# 21859  Mumbai  2015-01-05   25.5  58.53  ...      0.0     0.0  73.0  Satisfactory
#
# [5 rows x 16 columns]

# %%
fig = px.line(Mumbai_data, x="Date", y="PM2.5", width=800, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bd2852dc-4221-445b-b248-d9ed9fba62e9" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd2852dc-4221-445b-b248-d9ed9fba62e9")) {
#                     Plotly.newPlot(
#                         'bd2852dc-4221-445b-b248-d9ed9fba62e9',
# ...

# %%
df_year_19_20=Mumbai_data[Mumbai_data['Date']>='2019']

# %%
fig = px.line(df_year_19_20, x="Date", y="PM2.5")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6e6866ec-c27d-450e-85f3-84fa5f82fa5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e6866ec-c27d-450e-85f3-84fa5f82fa5a")) {
#                     Plotly.newPlot(
#                         '6e6866ec-c27d-450e-85f3-84fa5f82fa5a',
# ...

# %%
Mar_may_2019=Mumbai_data[(Mumbai_data['Date'] >= '2019-03') & (Mumbai_data['Date'] <= '2019-05')]
Mar_may_2020=Mumbai_data[(Mumbai_data['Date'] >= '2020-03') & (Mumbai_data['Date'] <= '2020-05')]

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# Effect Of lockdown in PM2.5

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2019['PM2.5'],
                    mode='lines+markers',
                    name='PM2.5 levels of 2019'))
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2020['PM2.5'],
                    mode='lines+markers',
                    name='PM2.5 levels of 2020'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b2b17cc4-919a-46f4-81ac-37781ff51514" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2b17cc4-919a-46f4-81ac-37781ff51514")) {
#                     Plotly.newPlot(
#                         'b2b17cc4-919a-46f4-81ac-37781ff51514',
# ...

# %% [markdown]
# PM10 in Mumbai

# %%
fig = px.line(Mumbai_data, x="Date", y="PM10")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a7c967b6-6a5e-4182-bafe-d812279f3fdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7c967b6-6a5e-4182-bafe-d812279f3fdd")) {
#                     Plotly.newPlot(
#                         'a7c967b6-6a5e-4182-bafe-d812279f3fdd',
# ...

# %%
fig = px.line(df_year_19_20, x="Date", y="PM10")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="56cd0a61-9297-44b7-9306-bfea84c200a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56cd0a61-9297-44b7-9306-bfea84c200a8")) {
#                     Plotly.newPlot(
#                         '56cd0a61-9297-44b7-9306-bfea84c200a8',
# ...

# %% [markdown]
# Effect of lockdown in PM10

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2019['PM10'],
                    mode='lines+markers',
                    name='PM10 levels of Mumbai march and april month of 2019'))
fig.add_trace(go.Scatter(x=Mar_may_2019['Date'], y=Mar_may_2020['PM10'],
                    mode='lines+markers',
                    name='PM10 levels of Mumbai march and april month of 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0efbe4e2-d5c2-4051-9f56-0d561222af6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0efbe4e2-d5c2-4051-9f56-0d561222af6c")) {
#                     Plotly.newPlot(
#                         '0efbe4e2-d5c2-4051-9f56-0d561222af6c',
# ...

# %% [markdown]
# NO levels in Mumbai

# %%
fig = px.line(Mumbai_data, x="Date", y="NO")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87afd120-7a0d-4141-ae50-aad90fc2f832" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87afd120-7a0d-4141-ae50-aad90fc2f832")) {
#                     Plotly.newPlot(
#                         '87afd120-7a0d-4141-ae50-aad90fc2f832',
# ...

# %%
fig = px.line(df_year_19_20, x="Date", y="NO")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ee04e3ed-a2e7-41fb-96af-ce9265116ec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee04e3ed-a2e7-41fb-96af-ce9265116ec3")) {
#                     Plotly.newPlot(
#                         'ee04e3ed-a2e7-41fb-96af-ce9265116ec3',
# ...

# %%
march24_2019=Mumbai_data[(Mumbai_data['Date'] >= '2019-03-23') & (Mumbai_data['Date'] <= '2019-04-15')]
march24_2020=Mumbai_data[(Mumbai_data['Date'] >= '2020-03-23') & (Mumbai_data['Date'] <= '2020-04-15')]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2019['NO'],
                    mode='lines+markers',
                    name='NO levels of Mumbai from 23-march-2019  to 15-april 2019'))
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2020['NO'],
                    mode='lines+markers',
                    name='NO levels of Mumbai from 23-march-2020  to 15-april 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="de1528c8-d270-450d-aee8-77a86fe8fed9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de1528c8-d270-450d-aee8-77a86fe8fed9")) {
#                     Plotly.newPlot(
#                         'de1528c8-d270-450d-aee8-77a86fe8fed9',
# ...

# %% [markdown]
# NO2 level in Mumbai

# %%
fig = px.line(Mumbai_data, x="Date", y="NO2")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7aeef6ae-8eb7-440f-8307-bd32e6100246" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7aeef6ae-8eb7-440f-8307-bd32e6100246")) {
#                     Plotly.newPlot(
#                         '7aeef6ae-8eb7-440f-8307-bd32e6100246',
# ...

# %%
fig = px.line(df_year_19_20, x="Date", y="NO2")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1447e333-91dc-47a5-99fd-bf298adc4099" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1447e333-91dc-47a5-99fd-bf298adc4099")) {
#                     Plotly.newPlot(
#                         '1447e333-91dc-47a5-99fd-bf298adc4099',
# ...

# %% [markdown]
# Lockdown Effect in NO2 level

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2019['NO2'],
                    mode='lines+markers',
                    name='NO2 levels of Mumbai from 23-march-2019  to 15-april 2019'))
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2020['NO2'],
                    mode='lines+markers',
                    name='NO2 levels of Mumbai from 23-march-2020  to 15-april 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b329ed3d-35b1-4edb-a6cd-d4da943cf66f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b329ed3d-35b1-4edb-a6cd-d4da943cf66f")) {
#                     Plotly.newPlot(
#                         'b329ed3d-35b1-4edb-a6cd-d4da943cf66f',
# ...

# %% [markdown]
# Ozone or O3 level in Mumbai

# %%
fig = px.line(Mumbai_data, x="Date", y="O3")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ce021419-759a-46ff-bee4-fcf92e310473" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ce021419-759a-46ff-bee4-fcf92e310473")) {
#                     Plotly.newPlot(
#                         'ce021419-759a-46ff-bee4-fcf92e310473',
# ...

# %%
fig = px.line(df_year_19_20, x="Date", y="O3")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c93b376c-aa32-4b55-9a79-65db8dc568b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c93b376c-aa32-4b55-9a79-65db8dc568b5")) {
#                     Plotly.newPlot(
#                         'c93b376c-aa32-4b55-9a79-65db8dc568b5',
# ...

# %% [markdown]
# Lockdown Effect in O3 level

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2019['O3'],
                    mode='lines+markers',
                    name='O3 levels of Mumbai from 23-march-2019  to 15-april 2019'))
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2020['O3'],
                    mode='lines+markers',
                    name='O3 levels of Mumbai from 23-march-2020  to 15-april 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="439c6dc0-eaeb-4dcb-aa70-b4af116a0d22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("439c6dc0-eaeb-4dcb-aa70-b4af116a0d22")) {
#                     Plotly.newPlot(
#                         '439c6dc0-eaeb-4dcb-aa70-b4af116a0d22',
# ...

# %% [markdown]
# Sulpher Dioxide levels in Mumbai (SO2)

# %%
fig = px.line(Mumbai_data, x="Date", y="SO2")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9dd4db43-c421-4115-bd0a-339a89d8c6f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9dd4db43-c421-4115-bd0a-339a89d8c6f7")) {
#                     Plotly.newPlot(
#                         '9dd4db43-c421-4115-bd0a-339a89d8c6f7',
# ...

# %% [markdown]
# Lockdown effect in SO2 levels in Mumbai

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2019['SO2'],
                    mode='lines+markers',
                    name='SO2 levels of Mumbai from 23-march-2019  to 15-april 2019'))
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2020['SO2'],
                    mode='lines+markers',
                    name='SO2 levels of Mumbai from 23-march-2020  to 15-april 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9fbf432e-0e5f-487d-9ac1-d343c2011dcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9fbf432e-0e5f-487d-9ac1-d343c2011dcb")) {
#                     Plotly.newPlot(
#                         '9fbf432e-0e5f-487d-9ac1-d343c2011dcb',
# ...

# %% [markdown]
# BTX levels (Benzene,Toluene,Xylene)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=Mumbai_data['Date'], y=Mumbai_data['Benzene'],
                    mode='lines',
                    name='Benzene level'))
fig.add_trace(go.Scatter(x=Mumbai_data['Date'], y=Mumbai_data['Toluene'],
                    mode='lines',
                    name='Toluene level'))
fig.add_trace(go.Scatter(x=Mumbai_data['Date'], y=Mumbai_data['Xylene'],
                    mode='lines',
                    name='Xylene level'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="88548baf-a69c-4bd3-8648-d0a856c2dced" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88548baf-a69c-4bd3-8648-d0a856c2dced")) {
#                     Plotly.newPlot(
#                         '88548baf-a69c-4bd3-8648-d0a856c2dced',
# ...

# %% [markdown]
# BTX levels month-wise

# %%
data_2019=Mumbai_data[(Mumbai_data['Date'] >= '2019') & (Mumbai_data['Date'] < '2020')]
data_2019['BTX']=data_2019['Benzene'] + data_2019['Toluene'] + data_2019['Xylene']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.line(data_2019, x="Date", y="BTX")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66e881a2-f591-48a8-bddf-bee9700e3ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66e881a2-f591-48a8-bddf-bee9700e3ab5")) {
#                     Plotly.newPlot(
#                         '66e881a2-f591-48a8-bddf-bee9700e3ab5',
# ...

# %% [markdown]
# Air Quality Index of Mumbai

# %%
fig = px.line(Mumbai_data, x="Date", y="AQI")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ee8ad5f-c713-4552-8ec9-932a97f651c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ee8ad5f-c713-4552-8ec9-932a97f651c0")) {
#                     Plotly.newPlot(
#                         '4ee8ad5f-c713-4552-8ec9-932a97f651c0',
# ...

# %% [markdown]
# Effect on AQI levels of Mumbai due to lockdown

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2019['AQI'],
                    mode='lines+markers',
                    name='AQI levels of Mumbai from 23-march-2019  to 15-april 2019'))
fig.add_trace(go.Scatter(x=march24_2019['Date'], y=march24_2020['AQI'],
                    mode='lines+markers',
                    name='AQI levels of Mumbai from 23-march-2020  to 15-april 2020'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="968cda0b-d2c1-4d83-be76-5a5c60a88aad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("968cda0b-d2c1-4d83-be76-5a5c60a88aad")) {
#                     Plotly.newPlot(
#                         '968cda0b-d2c1-4d83-be76-5a5c60a88aad',
# ...

# %%
march24_2019['AQI'].mean()
# Out:
# 106.45833333333333

# %%
march24_2020['AQI'].mean()
# Out:
# 78.95833333333333
